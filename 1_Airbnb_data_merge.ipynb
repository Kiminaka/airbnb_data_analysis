# %% [markdown]
# # Goal
# -  Join the two tables on review id

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import graphlab as gl
# %matplotlib inline

# %% [markdown]
# ## Let's read data
#
# ### Listing details

# %%
listing_detail = pd.read_csv('data/listings_detail.csv', index_col=None)

# %%
print listing_detail.info()
print np.shape(listing_detail)
listing_detail.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7029 entries, 0 to 7028
# Data columns (total 92 columns):
# id                                  7029 non-null int64
# listing_url                         7029 non-null object
# scrape_id                           7029 non-null int64
# last_scraped                        7029 non-null object
# name                                7029 non-null object
# summary                             6457 non-null object
# space                               5652 non-null object
# description                         7026 non-null object
# experiences_offered                 7029 non-null object
# neighborhood_overview               4371 non-null object
# notes                               3212 non-null object
# transit                             4571 non-null object
# thumbnail_url                       6504 non-null object
# medium_url                          6504 non-null object
# picture_url                         7029 non-null object
# xl_picture_url                      6504 non-null object
# host_id                             7029 non-null int64
# host_url                            7029 non-null object
# host_name                           7028 non-null object
# host_since                          7028 non-null object
# host_location                       7018 non-null object
# host_about                          5454 non-null object
# host_response_time                  6178 non-null object
# host_response_rate                  6178 non-null object
# host_acceptance_rate                5901 non-null object
# host_is_superhost                   7028 non-null object
# host_thumbnail_url                  7028 non-null object
# host_picture_url                    7028 non-null object
# host_neighbourhood                  6639 non-null object
# host_listings_count                 7028 non-null float64
# host_total_listings_count           7028 non-null float64
# host_verifications                  7029 non-null object
# host_has_profile_pic                7028 non-null object
# host_identity_verified              7028 non-null object
# street                              7029 non-null object
# neighbourhood                       6483 non-null object
# neighbourhood_cleansed              7029 non-null object
# neighbourhood_group_cleansed        0 non-null float64
# city                                7028 non-null object
# state                               7028 non-null object
# zipcode                             7007 non-null float64
# market                              7029 non-null object
# smart_location                      7029 non-null object
# country_code                        7029 non-null object
# country                             7029 non-null object
# latitude                            7029 non-null float64
# longitude                           7029 non-null float64
# is_location_exact                   7029 non-null object
# property_type                       7024 non-null object
# room_type                           7029 non-null object
# accommodates                        7029 non-null int64
# bathrooms                           6974 non-null float64
# bedrooms                            7020 non-null float64
# beds                                7017 non-null float64
# bed_type                            7029 non-null object
# amenities                           7029 non-null object
# square_feet                         245 non-null float64
# price                               7029 non-null object
# weekly_price                        3334 non-null object
# monthly_price                       2573 non-null object
# security_deposit                    3508 non-null object
# cleaning_fee                        5133 non-null object
# guests_included                     7029 non-null int64
# extra_people                        7029 non-null object
# minimum_nights                      7029 non-null int64
# maximum_nights                      7029 non-null int64
# calendar_updated                    7029 non-null object
# has_availability                    7029 non-null object
# availability_30                     7029 non-null int64
# availability_60                     7029 non-null int64
# availability_90                     7029 non-null int64
# availability_365                    7029 non-null int64
# calendar_last_scraped               7029 non-null object
# number_of_reviews                   7029 non-null int64
# first_review                        5698 non-null object
# last_review                         5698 non-null object
# review_scores_rating                5641 non-null float64
# review_scores_accuracy              5623 non-null float64
# review_scores_cleanliness           5622 non-null float64
# review_scores_checkin               5624 non-null float64
# review_scores_communication         5628 non-null float64
# review_scores_location              5627 non-null float64
# review_scores_value                 5629 non-null float64
# requires_license                    7029 non-null object
# license                             697 non-null object
# jurisdiction_names                  7014 non-null object
# instant_bookable                    7029 non-null object
# cancellation_policy                 7029 non-null object
# require_guest_profile_picture       7029 non-null object
# require_guest_phone_verification    7029 non-null object
# calculated_host_listings_count      7029 non-null int64
# reviews_per_month                   5698 non-null float64
# dtypes: float64(18), int64(13), object(61)
# memory usage: 5.0+ MB
# None
# (7029, 92)
#         id                           listing_url       scrape_id last_scraped  \
# 0  1162609  https://www.airbnb.com/rooms/1162609  20151101181058   2015-11-02
# 1  6032828  https://www.airbnb.com/rooms/6032828  20151101181058   2015-11-01
# 2  6938818  https://www.airbnb.com/rooms/6938818  20151101181058   2015-11-02
# 3  8087607  https://www.airbnb.com/rooms/8087607  20151101181058   2015-11-02
# 4  4781448  https://www.airbnb.com/rooms/4781448  20151101181058   2015-11-02
#
#                                   name  \
# 0         Lovely One Bedroom Apartment
# 1               Historic Seacliff Home
# 2                  Best Secret in Town
# 3    Single Room Beautiful Beach Condo
# 4  3 Bd 2.5 Ba Full Flat Condo w Views
#
#                                              summary  \
# 0  This is a big well designed space. Our neighbo...
# 1  Beautiful charmng multi- bedroom home in prest...
# 2  Convenience is the key for your travel. Walkin...
# 3  When I travel, my quiet beach side condo makes...
# 4  Our family-friendly condo is located in San Fr...
#
#                                                space  \
# 0  This is a great one bedroom apartment. It is a...
# 1                                                NaN
# 2  The room is spacious and it is on the top leve...
# 3                                                NaN
# 4  Open concept living, dining area has great cit...
#
#                                          description experiences_offered  \
# 0  This is a big well designed space. Our neighbo...                none
# 1  Beautiful charmng multi- bedroom home in prest...                none
# 2  Convenience is the key for your travel. Walkin...                none
# 3  When I travel, my quiet beach side condo makes...                none
# 4  Our family-friendly condo is located in San Fr...                none
#
#                                neighborhood_overview        ...         \
# 0                                                NaN        ...
# 1                                                NaN        ...
# 2  It is in the city and close to everything. Par...        ...
# 3                                                NaN        ...
# 4  We are located across the street from Lincoln ...        ...
#
#   review_scores_value requires_license  \
# 0                   9                t
# 1                 NaN                t
# 2                   9                t
# 3                 NaN                t
# 4                  10                t
#
#                                              license jurisdiction_names  \
# 0                                                NaN      SAN FRANCISCO
# 1                                                NaN      SAN FRANCISCO
# 2  S. F. Short-Term Residential Rental Registrati...      SAN FRANCISCO
# 3                                                NaN      SAN FRANCISCO
# 4                                                NaN      SAN FRANCISCO
#
#   instant_bookable cancellation_policy  require_guest_profile_picture  \
# 0                f              strict                              f
# 1                f            flexible                              f
# 2                f              strict                              f
# 3                f            flexible                              f
# 4                t              strict                              f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
# 1                                f                              1
# 2                                f                              1
# 3                                f                              1
# 4                                f                              1
#
#   reviews_per_month
# 0              0.28
# 1               NaN
# 2              2.33
# 3               NaN
# 4              0.36
#
# [5 rows x 92 columns]

# %%
len(listing_detail.columns)
# Out:
# 92

# %% [markdown]
# ### Pick columns
# - I hand-selected columns that would be useful for the later analyses.

# %%
columns_listing_detail = pd.read_csv('data/columns.txt', names=['col']) #hand-selected columns from original data
columns_listing_detail = [item for item in columns_listing_detail['col']]

# %%
listings = listing_detail[columns_listing_detail]
listings.head()
# Out:
#         id                           listing_url  \
# 0  1162609  https://www.airbnb.com/rooms/1162609
# 1  6032828  https://www.airbnb.com/rooms/6032828
# 2  6938818  https://www.airbnb.com/rooms/6938818
# 3  8087607  https://www.airbnb.com/rooms/8087607
# 4  4781448  https://www.airbnb.com/rooms/4781448
#
#                                   name  \
# 0         Lovely One Bedroom Apartment
# 1               Historic Seacliff Home
# 2                  Best Secret in Town
# 3    Single Room Beautiful Beach Condo
# 4  3 Bd 2.5 Ba Full Flat Condo w Views
#
#                                              summary  \
# 0  This is a big well designed space. Our neighbo...
# 1  Beautiful charmng multi- bedroom home in prest...
# 2  Convenience is the key for your travel. Walkin...
# 3  When I travel, my quiet beach side condo makes...
# 4  Our family-friendly condo is located in San Fr...
#
#                                                space  \
# 0  This is a great one bedroom apartment. It is a...
# 1                                                NaN
# 2  The room is spacious and it is on the top leve...
# 3                                                NaN
# 4  Open concept living, dining area has great cit...
#
#                                          description  \
# 0  This is a big well designed space. Our neighbo...
# 1  Beautiful charmng multi- bedroom home in prest...
# 2  Convenience is the key for your travel. Walkin...
# 3  When I travel, my quiet beach side condo makes...
# 4  Our family-friendly condo is located in San Fr...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1                                                NaN
# 2  It is in the city and close to everything. Par...
# 3                                                NaN
# 4  We are located across the street from Lincoln ...
#
#                                                notes  \
# 0                                                NaN
# 1                                                NaN
# 2  The summer in San Francisco is cooler than any...
# 3                                                NaN
# 4                       2 night minimum stay please.
#
#                                              transit   host_id  \
# 0                                                NaN   6368122
# 1                                                NaN  30384615
# 2  If you are on budget, the public transportatio...  36381578
# 3                                                NaN   3264449
# 4  Easy bus access to the entire city with 3 bus ...  13112558
#
#          ...        review_scores_rating review_scores_accuracy  \
# 0        ...                          89                      9
# 1        ...                         NaN                    NaN
# 2        ...                          92                      9
# 3        ...                         NaN                    NaN
# 4        ...                         100                     10
#
#   review_scores_cleanliness review_scores_checkin review_scores_communication  \
# 0                         9                    10                          10
# 1                       NaN                   NaN                         NaN
# 2                         9                    10                           9
# 3                       NaN                   NaN                         NaN
# 4                        10                    10                          10
#
#   review_scores_location review_scores_value instant_bookable  \
# 0                      9                   9                f
# 1                    NaN                 NaN                f
# 2                      9                   9                f
# 3                    NaN                 NaN                f
# 4                     10                  10                t
#
#    cancellation_policy reviews_per_month
# 0               strict              0.28
# 1             flexible               NaN
# 2               strict              2.33
# 3             flexible               NaN
# 4               strict              0.36
#
# [5 rows x 53 columns]

# %% [markdown]
# ### Review data

# %%
reviews = pd.read_csv('data/reviews.csv')
print reviews.info()
reviews.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 143237 entries, 0 to 143236
# Data columns (total 6 columns):
# listing_id       143237 non-null int64
# id               143237 non-null int64
# date             143237 non-null object
# reviewer_id      143237 non-null int64
# reviewer_name    143237 non-null object
# comments         143201 non-null object
# dtypes: int64(3), object(3)
# memory usage: 7.6+ MB
# None
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     1994427  10612780  2014-02-27      4918890         Katie
# 1     1994427  49925683  2015-10-07     44613424        Steven
# 2     1994427  50537634  2015-10-12      7616696     Marsilius
# 3     1994427  51077613  2015-10-17     16703590        Robert
# 4     1994427  52109034  2015-10-26      6183409         Steve
#
#                                             comments
# 0  Great host. Provided special gift basket upon ...
# 1  Great host. Met me at apartment. Place was cle...
# 2  Syeda hosted my parents for four days during t...
# 3  I had a great experience at Syeda's Airbnb! It...
# 4  Great location!  Warm, welcoming host.  This w...

# %%
reviews = reviews.rename(columns={'listing_id': 'id', 
                        'id': 'review_id',})

# %%
print np.shape(listings)
print np.shape(reviews)
# Out:
# (7029, 53)
# (143237, 6)

# %%
listings.head(1)
# Out:
#         id                           listing_url  \
# 0  1162609  https://www.airbnb.com/rooms/1162609
#
#                            name  \
# 0  Lovely One Bedroom Apartment
#
#                                              summary  \
# 0  This is a big well designed space. Our neighbo...
#
#                                                space  \
# 0  This is a great one bedroom apartment. It is a...
#
#                                          description neighborhood_overview  \
# 0  This is a big well designed space. Our neighbo...                   NaN
#
#   notes transit  host_id        ...        review_scores_rating  \
# 0   NaN     NaN  6368122        ...                          89
#
#   review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 0                      9                         9                    10
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                          10                      9                   9
#
#   instant_bookable  cancellation_policy reviews_per_month
# 0                f               strict              0.28
#
# [1 rows x 53 columns]

# %%
reviews.head(1)
# Out:
#         id  review_id        date  reviewer_id reviewer_name  \
# 0  1994427   10612780  2014-02-27      4918890         Katie
#
#                                             comments
# 0  Great host. Provided special gift basket upon ...

# %% [markdown]
# ## Merge tables
# - Inner join listings and reviews on "id"

# %%
df =  pd.DataFrame.merge(reviews, listings, left_on='id', right_on='id', how='inner')
print np.shape(df)
df.head()
# Out:
# (143237, 58)
#         id  review_id        date  reviewer_id reviewer_name  \
# 0  1994427   10612780  2014-02-27      4918890         Katie
# 1  1994427   49925683  2015-10-07     44613424        Steven
# 2  1994427   50537634  2015-10-12      7616696     Marsilius
# 3  1994427   51077613  2015-10-17     16703590        Robert
# 4  1994427   52109034  2015-10-26      6183409         Steve
#
#                                             comments  \
# 0  Great host. Provided special gift basket upon ...
# 1  Great host. Met me at apartment. Place was cle...
# 2  Syeda hosted my parents for four days during t...
# 3  I had a great experience at Syeda's Airbnb! It...
# 4  Great location!  Warm, welcoming host.  This w...
#
#                             listing_url                   name  \
# 0  https://www.airbnb.com/rooms/1994427  One Bedroom apartment
# 1  https://www.airbnb.com/rooms/1994427  One Bedroom apartment
# 2  https://www.airbnb.com/rooms/1994427  One Bedroom apartment
# 3  https://www.airbnb.com/rooms/1994427  One Bedroom apartment
# 4  https://www.airbnb.com/rooms/1994427  One Bedroom apartment
#
#                                              summary  \
# 0  Charming one bedroom in the Mission!  Close to...
# 1  Charming one bedroom in the Mission!  Close to...
# 2  Charming one bedroom in the Mission!  Close to...
# 3  Charming one bedroom in the Mission!  Close to...
# 4  Charming one bedroom in the Mission!  Close to...
#
#                                                space        ...         \
# 0  The bedroom fits two on the full sized bed and...        ...
# 1  The bedroom fits two on the full sized bed and...        ...
# 2  The bedroom fits two on the full sized bed and...        ...
# 3  The bedroom fits two on the full sized bed and...        ...
# 4  The bedroom fits two on the full sized bed and...        ...
#
#   review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 0                   92                      9                         9
# 1                   92                      9                         9
# 2                   92                      9                         9
# 3                   92                      9                         9
# 4                   92                      9                         9
#
#   review_scores_checkin  review_scores_communication review_scores_location  \
# 0                    10                           10                     10
# 1                    10                           10                     10
# 2                    10                           10                     10
# 3                    10                           10                     10
# 4                    10                           10                     10
#
#   review_scores_value instant_bookable cancellation_policy reviews_per_month
# 0                   9                f              strict              0.24
# 1                   9                f              strict              0.24
# 2                   9                f              strict              0.24
# 3                   9                f              strict              0.24
# 4                   9                f              strict              0.24
#
# [5 rows x 58 columns]

# %%
print np.shape(df)
print np.shape(df2)
# Out:
# (143237, 58)
# (144568, 58)

# %%
pwd
# Out:
# u'/Users/kimitakanakazawa/Dropbox/galvanizeU/FP6003_6004'

# %% [markdown]
# ## Export with csv format

# %%
# listings.to_csv('data/listings_new.csv')
# reviews.to_csv('data/reviews_new.csv')
# df.to_csv('data/df_new.csv')
